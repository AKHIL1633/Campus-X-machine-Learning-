# %%
import cv2

# %%
# Read the image using OpenCV
image = cv2.imread('/content/Sharukh_image.jpeg')

# %%
image.shape
# Out:
# (225, 225, 3)

# %%
image
# Out:
# array([[[ 10,  10,  16],
#         [ 10,  10,  16],
#         [ 11,  11,  17],
#         ...,
#         [ 16,   5,  13],
#         [ 16,   5,  13],
#         [ 13,   5,  12]],
#
#        [[ 10,  10,  16],
#         [ 10,  10,  16],
#         [ 11,  11,  17],
#         ...,
#         [ 16,   5,  13],
#         [ 16,   5,  13],
#         [ 13,   5,  12]],
#
#        [[ 11,  11,  17],
#         [ 11,  11,  17],
#         [ 11,  11,  17],
#         ...,
#         [ 16,   5,  13],
#         [ 16,   5,  13],
#         [ 13,   5,  12]],
#
#        ...,
#
#        [[132, 146, 164],
#         [126, 140, 158],
#         [130, 144, 162],
#         ...,
#         [ 19,  11,  18],
#         [ 33,  25,  32],
#         [ 30,  21,  31]],
#
#        [[124, 138, 156],
#         [117, 131, 149],
#         [121, 135, 153],
#         ...,
#         [ 37,  28,  38],
#         [ 33,  24,  34],
#         [ 31,  22,  32]],
#
#        [[122, 136, 154],
#         [119, 133, 151],
#         [128, 142, 160],
#         ...,
#         [ 33,  23,  35],
#         [ 33,  23,  35],
#         [ 32,  22,  34]]], dtype=uint8)

# %%
# Print the pixel values
print(image)
# Out:
# [[[ 10  10  16]
#   [ 10  10  16]
#   [ 11  11  17]
#   ...
#   [ 16   5  13]
#   [ 16   5  13]
#   [ 13   5  12]]
#
#  [[ 10  10  16]
#   [ 10  10  16]
#   [ 11  11  17]
#   ...
#   [ 16   5  13]
#   [ 16   5  13]
#   [ 13   5  12]]
#
#  [[ 11  11  17]
#   [ 11  11  17]
#   [ 11  11  17]
#   ...
#   [ 16   5  13]
#   [ 16   5  13]
#   [ 13   5  12]]
#
#  ...
#
#  [[132 146 164]
#   [126 140 158]
#   [130 144 162]
#   ...
#   [ 19  11  18]
#   [ 33  25  32]
#   [ 30  21  31]]
#
#  [[124 138 156]
#   [117 131 149]
#   [121 135 153]
#   ...
#   [ 37  28  38]
#   [ 33  24  34]
#   [ 31  22  32]]
#
#  [[122 136 154]
#   [119 133 151]
#   [128 142 160]
#   ...
#   [ 33  23  35]
#   [ 33  23  35]
#   [ 32  22  34]]]

# %%
# image = cv2.imread()

# %%
import cv2

# Load the color image
image = cv2.imread('/content/Sharukh_image.jpeg')

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image
# Out:
# array([[ 12,  12,  13, ...,   9,   9,   8],
#        [ 12,  12,  13, ...,   9,   9,   8],
#        [ 13,  13,  13, ...,   9,   9,   8],
#        ...,
#        [150, 144, 148, ...,  14,  28,  25],
#        [142, 135, 139, ...,  32,  28,  26],
#        [140, 137, 146, ...,  28,  28,  27]], dtype=uint8)

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Save or display the grayscale image
cv2.imwrite('gray_image.jpg', gray_image)
cv2.imshow('Grayscale Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
